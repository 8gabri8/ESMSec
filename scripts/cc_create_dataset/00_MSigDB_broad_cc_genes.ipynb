# %% [markdown]
# # Goal
#
# Define an inital broad set of cc related genes starting from MSigDB.
#
# Simple keywords are used to find all relevants genesets.

# %%
# Autorelaod
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
os.chdir("/home/gdallagl/myworkdir/ESMSec")
print(f"Working directory successfully changed to: {os.getcwd()}")

import utils.my_functions as mf
import utils.dataset_functions as dataf

config_file="/home/gdallagl/myworkdir/ESMSec/config/config.yaml"
config = mf.load_config(config_file)

mf.set_all_seeds(config["random_seed"])
# Out:
# Working directory successfully changed to: /home/gdallagl/myworkdir/ESMSec
# Seeds set successfully to 42 for random, numpy, and PyTorch (if used).

# %% [markdown]
# # Keywords

# %%
# Updated keywords pattern with word boundaries to avoid false matches
KEYWORDS_PATTERN = "|".join([
    "_PROLIFERATION_", #avoid "proliferative" "proliferator"
    "_CYCLING",  # avoid "recycling"
    "CELL_CYCLE",
    "_CC_", "_G1_", "_S_PHASE_", "_G2_", "_M_PHASE_", # avoid "aCCumbens"
    "MITOSIS", "MITOTIC",
    "CDK",
    "CHECKPOINT"
])

# Exclusion pattern
EXCLUSION_PATTERN = r"MEIOTIC|MEIOSIS|FATTY_ACID_CYCLING_MODEL"

# %% [markdown]
# # Read MSigDB

# %%
### 1) Transform jsons into df
df_genesets = dataf.load_json_folder_to_df(config["data_paths"]["MSigDB_all_data"])
df_genesets = df_genesets.drop_duplicates(subset=['set_name'], keep='first')
display(df_genesets.head(2)); print(df_genesets.shape)
# Out:
#     set_name    collection systematicName      pmid exactSource  \
# 0  MIR153_5P  C3:MIR:MIRDB         M30412  31504780
# 1    MIR8485  C3:MIR:MIRDB         M30413  31504780
#
#                                   externalDetailsURL  \
# 0  http://mirdb.org/cgi-bin/mature_mir.cgi?name=h...
# 1  http://mirdb.org/cgi-bin/mature_mir.cgi?name=h...
#
#                                            msigdbURL  \
# 0  https://www.gsea-msigdb.org/gsea/msigdb/human/...
# 1  https://www.gsea-msigdb.org/gsea/msigdb/human/...
#
#                                          geneSymbols filteredBySimilarity  \
# 0  [A1CF, AAK1, AASDHPPT, ABCE1, ABHD2, ABI2, ACB...                   []
# 1  [AAK1, ABHD18, ABL2, ABLIM1, ACVR1, ACVR2B, AC...                   []
#
#   externalNamesForSimilarTerms                   source_file
# 0                           []  c3.mir.mirdb.v2025.1.Hs.json
# 1                           []  c3.mir.mirdb.v2025.1.Hs.json
# (35134, 11)

# %%
### 2) Select only geneset related to interested fiedl
mask_include = df_genesets["set_name"].str.contains(KEYWORDS_PATTERN, case=False, regex=True)
mask_exclude = df_genesets["set_name"].str.contains(EXCLUSION_PATTERN, case=False, regex=True)
df_genesets_cell_cycle = df_genesets[mask_include & ~mask_exclude].copy()

NUMBER_POSITIVE_GENESETS = df_genesets_cell_cycle.shape[0]
print("Number of positive genesets:", NUMBER_POSITIVE_GENESETS)
list(df_genesets_cell_cycle['set_name'].sort_values())
# Out:
# Number of positive genesets: 291
# ['ACOSTA_PROLIFERATION_INDEPENDENT_MYC_TARGETS_DN',
#  'ACOSTA_PROLIFERATION_INDEPENDENT_MYC_TARGETS_UP',
#  'BENPORATH_CYCLING_GENES',
#  'BIOCARTA_CDK5_PATHWAY',
#  'BIOCARTA_G1_PATHWAY',
#  'BIOCARTA_G2_PATHWAY',
#  'BOYAULT_LIVER_CANCER_SUBCLASS_G1_DN',
#  'BOYAULT_LIVER_CANCER_SUBCLASS_G1_UP',
#  'CHIANG_LIVER_CANCER_SUBCLASS_PROLIFERATION_DN',
#  'CHIANG_LIVER_CANCER_SUBCLASS_PROLIFERATION_UP',
#  'DONATO_CELL_CYCLE_TRETINOIN',
#  'EGUCHI_CELL_CYCLE_RB1_TARGETS',
#  'FISCHER_G1_S_CELL_CYCLE',
#  'FISCHER_G2_M_CELL_CYCLE',
#  'FUJIWARA_PARK2_HEPATOCYTE_PROLIFERATION_DN',
#  'FUJIWARA_PARK2_HEPATOCYTE_PROLIFERATION_UP',
#  'GAVISH_3CA_MALIGNANT_METAPROGRAM_2_CELL_CYCLE_G1_S',
#  'GAVISH_3CA_METAPROGRAM_B_CELLS_CELL_CYCLE',
#  'GAVISH_3CA_METAPROGRAM_CD4_T_CELLS_CELL_CYCLE',
#  'GAVISH_3CA_METAPROGRAM_CD8_T_CELLS_CELL_CYCLE',
#  'GAVISH_3CA_METAPROGRAM_ENDOTHELIAL_CELL_CYCLE',
#  'GAVISH_3CA_METAPROGRAM_EPITHELIAL_CELL_CYCLE',
#  'GAVISH_3CA_METAPROGRAM_FIBROBLASTS_CELL_CYCLE',
#  'GAVISH_3CA_METAPROGRAM_MACROPHAGES_CELL_CYCLE',
#  'GEORGES_CELL_CYCLE_MIR192_TARGETS',
#  'GNF2_CDKN1C',
#  'GOBP_ATTACHMENT_OF_MITOTIC_SPINDLE_MICROTUBULES_TO_KINETOCHORE',
#  'GOBP_BLOOD_VESSEL_ENDOTHELIAL_CELL_PROLIFERATION_INVOLVED_IN_SPROUTING_ANGIOGENESIS',
#  'GOBP_B_CELL_PROLIFERATION_INVOLVED_IN_IMMUNE_RESPONSE',
#  'GOBP_CELL_CYCLE',
#  'GOBP_CELL_CYCLE_CHECKPOINT_SIGNALING',
#  'GOBP_CELL_CYCLE_DNA_REPLICATION',
#  'GOBP_CELL_CYCLE_DNA_REPLICATION_INITIATION',
#  'GOBP_CELL_CYCLE_G1_S_PHASE_TRANSITION',
#  'GOBP_CELL_CYCLE_G2_M_PHASE_TRANSITION',
#  'GOBP_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_CELL_CYCLE_PROCESS',
#  'GOBP_CELL_PROLIFERATION_INVOLVED_IN_HEART_MORPHOGENESIS',
#  'GOBP_CELL_PROLIFERATION_INVOLVED_IN_KIDNEY_DEVELOPMENT',
#  'GOBP_CELL_PROLIFERATION_INVOLVED_IN_METANEPHROS_DEVELOPMENT',
#  'GOBP_CELL_PROLIFERATION_IN_BONE_MARROW',
#  'GOBP_CELL_PROLIFERATION_IN_FOREBRAIN',
#  'GOBP_CELL_PROLIFERATION_IN_HINDBRAIN',
#  'GOBP_CELL_PROLIFERATION_IN_MIDBRAIN',
#  'GOBP_DNA_INTEGRITY_CHECKPOINT_SIGNALING',
#  'GOBP_DNA_REPLICATION_CHECKPOINT_SIGNALING',
#  'GOBP_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_LUNG_MORPHOGENESIS',
#  'GOBP_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_MAMMARY_GLAND_DUCT_ELONGATION',
#  'GOBP_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_PROSTATE_GLAND_DEVELOPMENT',
#  'GOBP_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_RENAL_TUBULE_MORPHOGENESIS',
#  'GOBP_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_SALIVARY_GLAND_MORPHOGENESIS',
#  'GOBP_ESTABLISHMENT_OF_MITOTIC_SISTER_CHROMATID_COHESION',
#  'GOBP_ESTABLISHMENT_OF_MITOTIC_SPINDLE_LOCALIZATION',
#  'GOBP_EXIT_FROM_MITOSIS',
#  'GOBP_G0_TO_G1_TRANSITION',
#  'GOBP_G1_TO_G0_TRANSITION',
#  'GOBP_G1_TO_G0_TRANSITION_INVOLVED_IN_CELL_DIFFERENTIATION',
#  'GOBP_MESENCHYMAL_CELL_PROLIFERATION_INVOLVED_IN_LUNG_DEVELOPMENT',
#  'GOBP_MICROTUBULE_CYTOSKELETON_ORGANIZATION_INVOLVED_IN_MITOSIS',
#  'GOBP_MITOTIC_CELL_CYCLE',
#  'GOBP_MITOTIC_CELL_CYCLE_CHECKPOINT_SIGNALING',
#  'GOBP_MITOTIC_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_MITOTIC_CELL_CYCLE_PROCESS',
#  'GOBP_MITOTIC_CHROMOSOME_CONDENSATION',
#  'GOBP_MITOTIC_CYTOKINESIS',
#  'GOBP_MITOTIC_CYTOKINETIC_PROCESS',
#  'GOBP_MITOTIC_DNA_INTEGRITY_CHECKPOINT_SIGNALING',
#  'GOBP_MITOTIC_DNA_REPLICATION',
#  'GOBP_MITOTIC_DNA_REPLICATION_CHECKPOINT_SIGNALING',
#  'GOBP_MITOTIC_G1_S_TRANSITION_CHECKPOINT_SIGNALING',
#  'GOBP_MITOTIC_G2_DNA_DAMAGE_CHECKPOINT_SIGNALING',
#  'GOBP_MITOTIC_G2_M_TRANSITION_CHECKPOINT',
#  'GOBP_MITOTIC_INTRA_S_DNA_DAMAGE_CHECKPOINT_SIGNALING',
#  'GOBP_MITOTIC_METAPHASE_CHROMOSOME_ALIGNMENT',
#  'GOBP_MITOTIC_NUCLEAR_DIVISION',
#  'GOBP_MITOTIC_NUCLEAR_MEMBRANE_DISASSEMBLY',
#  'GOBP_MITOTIC_NUCLEAR_MEMBRANE_ORGANIZATION',
#  'GOBP_MITOTIC_RECOMBINATION',
#  'GOBP_MITOTIC_SISTER_CHROMATID_COHESION',
#  'GOBP_MITOTIC_SISTER_CHROMATID_COHESION_CENTROMERIC',
#  'GOBP_MITOTIC_SISTER_CHROMATID_SEGREGATION',
#  'GOBP_MITOTIC_SISTER_CHROMATID_SEPARATION',
#  'GOBP_MITOTIC_SPINDLE_ASSEMBLY',
#  'GOBP_MITOTIC_SPINDLE_ELONGATION',
#  'GOBP_MITOTIC_SPINDLE_ORGANIZATION',
#  'GOBP_NEGATIVE_REGULATION_OF_BLOOD_VESSEL_ENDOTHELIAL_CELL_PROLIFERATION_INVOLVED_IN_SPROUTING_ANGIOGENESIS',
#  'GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE',
#  'GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_CHECKPOINT',
#  'GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_G1_S_PHASE_TRANSITION',
#  'GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_G2_M_PHASE_TRANSITION',
#  'GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_PROCESS',
#  'GOBP_NEGATIVE_REGULATION_OF_CELL_PROLIFERATION_INVOLVED_IN_KIDNEY_DEVELOPMENT',
#  'GOBP_NEGATIVE_REGULATION_OF_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_PROSTATE_GLAND_DEVELOPMENT',
#  'GOBP_NEGATIVE_REGULATION_OF_G0_TO_G1_TRANSITION',
#  'GOBP_NEGATIVE_REGULATION_OF_MITOTIC_CELL_CYCLE',
#  'GOBP_NEGATIVE_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_NEGATIVE_REGULATION_OF_MITOTIC_SPINDLE_ASSEMBLY_CHECKPOINT_SIGNALING',
#  'GOBP_POSITIVE_REGULATION_OF_ATTACHMENT_OF_MITOTIC_SPINDLE_MICROTUBULES_TO_KINETOCHORE',
#  'GOBP_POSITIVE_REGULATION_OF_BLOOD_VESSEL_ENDOTHELIAL_CELL_PROLIFERATION_INVOLVED_IN_SPROUTING_ANGIOGENESIS',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_CHECKPOINT',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_G1_S_PHASE_TRANSITION',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_G2_M_PHASE_TRANSITION',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_PROCESS',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_PROLIFERATION_INVOLVED_IN_HEART_MORPHOGENESIS',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_PROLIFERATION_INVOLVED_IN_KIDNEY_DEVELOPMENT',
#  'GOBP_POSITIVE_REGULATION_OF_CELL_PROLIFERATION_IN_BONE_MARROW',
#  'GOBP_POSITIVE_REGULATION_OF_DNA_DAMAGE_CHECKPOINT',
#  'GOBP_POSITIVE_REGULATION_OF_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_LUNG_MORPHOGENESIS',
#  'GOBP_POSITIVE_REGULATION_OF_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_WOUND_HEALING',
#  'GOBP_POSITIVE_REGULATION_OF_EXIT_FROM_MITOSIS',
#  'GOBP_POSITIVE_REGULATION_OF_G0_TO_G1_TRANSITION',
#  'GOBP_POSITIVE_REGULATION_OF_G1_S_TRANSITION_OF_MITOTIC_CELL_CYCLE',
#  'GOBP_POSITIVE_REGULATION_OF_METAPHASE_ANAPHASE_TRANSITION_OF_CELL_CYCLE',
#  'GOBP_POSITIVE_REGULATION_OF_MITOTIC_CELL_CYCLE',
#  'GOBP_POSITIVE_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_POSITIVE_REGULATION_OF_MITOTIC_CYTOKINESIS',
#  'GOBP_POSITIVE_REGULATION_OF_MITOTIC_NUCLEAR_DIVISION',
#  'GOBP_POSITIVE_REGULATION_OF_MITOTIC_SISTER_CHROMATID_SEGREGATION',
#  'GOBP_POSITIVE_REGULATION_OF_MITOTIC_SISTER_CHROMATID_SEPARATION',
#  'GOBP_POSITIVE_REGULATION_OF_NUCLEAR_CELL_CYCLE_DNA_REPLICATION',
#  'GOBP_POSITIVE_REGULATION_OF_SPINDLE_CHECKPOINT',
#  'GOBP_REGULATION_OF_ATTACHMENT_OF_MITOTIC_SPINDLE_MICROTUBULES_TO_KINETOCHORE',
#  'GOBP_REGULATION_OF_CELL_CYCLE',
#  'GOBP_REGULATION_OF_CELL_CYCLE_CHECKPOINT',
#  'GOBP_REGULATION_OF_CELL_CYCLE_G1_S_PHASE_TRANSITION',
#  'GOBP_REGULATION_OF_CELL_CYCLE_G2_M_PHASE_TRANSITION',
#  'GOBP_REGULATION_OF_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_REGULATION_OF_CELL_CYCLE_PROCESS',
#  'GOBP_REGULATION_OF_CELL_PROLIFERATION_INVOLVED_IN_KIDNEY_DEVELOPMENT',
#  'GOBP_REGULATION_OF_CELL_PROLIFERATION_IN_BONE_MARROW',
#  'GOBP_REGULATION_OF_DNA_DAMAGE_CHECKPOINT',
#  'GOBP_REGULATION_OF_EPITHELIAL_CELL_PROLIFERATION_INVOLVED_IN_LUNG_MORPHOGENESIS',
#  'GOBP_REGULATION_OF_EXIT_FROM_MITOSIS',
#  'GOBP_REGULATION_OF_G1_TO_G0_TRANSITION',
#  'GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE',
#  'GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION',
#  'GOBP_REGULATION_OF_MITOTIC_CENTROSOME_SEPARATION',
#  'GOBP_REGULATION_OF_MITOTIC_CYTOKINESIS',
#  'GOBP_REGULATION_OF_MITOTIC_NUCLEAR_DIVISION',
#  'GOBP_REGULATION_OF_MITOTIC_RECOMBINATION',
#  'GOBP_REGULATION_OF_MITOTIC_SISTER_CHROMATID_SEGREGATION',
#  'GOBP_REGULATION_OF_MITOTIC_SPINDLE_ASSEMBLY',
#  'GOBP_REGULATION_OF_NUCLEAR_CELL_CYCLE_DNA_REPLICATION',
#  'GOBP_REGULATION_OF_SPINDLE_CHECKPOINT',
#  'GOBP_RESOLUTION_OF_MITOTIC_RECOMBINATION_INTERMEDIATES',
#  'GOBP_RESPONSE_TO_CELL_CYCLE_CHECKPOINT_SIGNALING',
#  'GOCC_CHECKPOINT_CLAMP_COMPLEX',
#  'GOCC_CYCLIN_CDK_POSITIVE_TRANSCRIPTION_ELONGATION_FACTOR_COMPLEX',
#  'GOCC_MITOTIC_COHESIN_COMPLEX',
#  'GOCC_MITOTIC_SPINDLE',
#  'GOCC_MITOTIC_SPINDLE_ASTRAL_MICROTUBULE',
#  'GOCC_MITOTIC_SPINDLE_MICROTUBULE',
#  'GOCC_MITOTIC_SPINDLE_MIDZONE',
#  'GOCC_MITOTIC_SPINDLE_POLE',
#  'HALLMARK_G2M_CHECKPOINT',
#  'HALLMARK_MITOTIC_SPINDLE',
#  'HERNANDEZ_ABERRANT_MITOSIS_BY_DOCETACEL_2NM_DN',
#  'HERNANDEZ_ABERRANT_MITOSIS_BY_DOCETACEL_2NM_UP',
#  'HERNANDEZ_ABERRANT_MITOSIS_BY_DOCETACEL_4NM_DN',
#  'HERNANDEZ_ABERRANT_MITOSIS_BY_DOCETACEL_4NM_UP',
#  'HERNANDEZ_MITOTIC_ARREST_BY_DOCETAXEL_1_DN',
#  'HERNANDEZ_MITOTIC_ARREST_BY_DOCETAXEL_1_UP',
#  'HERNANDEZ_MITOTIC_ARREST_BY_DOCETAXEL_2_DN',
#  'HERNANDEZ_MITOTIC_ARREST_BY_DOCETAXEL_2_UP',
#  'HE_LIM_SUN_FETAL_LUNG_C2_CYCLING_DC_CELL',
#  'HE_LIM_SUN_FETAL_LUNG_C3_CYCLING_DEFINITIVE_ERYTHROBLAST',
#  'HE_LIM_SUN_FETAL_LUNG_C4_CYCLING_NK_CELL',
#  'HE_LIM_SUN_FETAL_LUNG_C4_CYCLING_T_CELL',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_G1_G2_DN',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_G1_G2_UP',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_UP',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_L1_G1_DN',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_L1_G1_UP',
#  'KEGG_CELL_CYCLE',
#  'KEGG_MEDICUS_PATHOGEN_EBV_EBNA3C_TO_CELL_CYCLE_G1_S_N00483',
#  'KEGG_MEDICUS_PATHOGEN_EBV_EBNA3C_TO_CELL_CYCLE_G1_S_N00484',
#  'KEGG_MEDICUS_PATHOGEN_EBV_EBNA3C_TO_P27_CELL_CYCLE_G1_S_N00264',
#  'KEGG_MEDICUS_PATHOGEN_EBV_EBNA3C_TO_P27_CELL_CYCLE_G1_S_N00482',
#  'KEGG_MEDICUS_PATHOGEN_HIV_VPR_TO_CDC25_CELL_CYCLE_G2M',
#  'KEGG_MEDICUS_PATHOGEN_HIV_VPR_TO_WEE1_CELL_CYCLE_G2M',
#  'KEGG_MEDICUS_PATHOGEN_HPV_E7_TO_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_PATHOGEN_HPV_E7_TO_P27_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_PATHOGEN_HTLV_1_TAX_TO_P21_CELL_CYCLE_G1_S_N00497',
#  'KEGG_MEDICUS_PATHOGEN_HTLV_1_TAX_TO_P21_CELL_CYCLE_G1_S_N00498',
#  'KEGG_MEDICUS_PATHOGEN_HTLV_1_TAX_TO_SPINDLE_ASSEMBLY_CHECKPOINT_SIGNALING',
#  'KEGG_MEDICUS_PATHOGEN_KSHV_VCYCLIN_TO_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_REFERENCE_ATR_P21_CELL_CYCLE_G2_M',
#  'KEGG_MEDICUS_REFERENCE_CDC25_CELL_CYCLE_G2_M',
#  'KEGG_MEDICUS_REFERENCE_MDM2_P21_CELL_CYCLE_G1_S_N00066',
#  'KEGG_MEDICUS_REFERENCE_MDM2_P21_CELL_CYCLE_G1_S_N00536',
#  'KEGG_MEDICUS_REFERENCE_P15_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_REFERENCE_P16_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_REFERENCE_P27_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_REFERENCE_P300_P21_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_REFERENCE_SPINDLE_ASSEMBLY_CHECKPOINT_SIGNALING',
#  'KEGG_MEDICUS_REFERENCE_WEE1_CELL_CYCLE_G2_M',
#  'KEGG_MEDICUS_VARIANT_AMPLIFIED_CCND1_TO_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_VARIANT_AMPLIFIED_CCNE_TO_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_VARIANT_AMPLIFIED_CDK4_TO_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_VARIANT_AMPLIFIED_MDM2_TO_P21_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_VARIANT_AMPLIFIED_MYC_TO_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_VARIANT_AMPLIFIED_MYC_TO_P27_CELL_CYCLE_G1_S',
#  'KEGG_MEDICUS_VARIANT_LOSS_OF_CDKN1B_TO_P27_CELL_CYCLE_G1_S',
#  'LAU_APOPTOSIS_CDKN2A_DN',
#  'LAU_APOPTOSIS_CDKN2A_UP',
#  'MOLENAAR_TARGETS_OF_CCND1_AND_CDK4_DN',
#  'MOLENAAR_TARGETS_OF_CCND1_AND_CDK4_UP',
#  'MORF_CDK2',
#  'PEART_HDAC_PROLIFERATION_CLUSTER_DN',
#  'PEART_HDAC_PROLIFERATION_CLUSTER_UP',
#  'PULVER_FOREY_CELLCYCLE_ENRICHED_TFS_G1_S',
#  'PULVER_FOREY_CELLCYCLE_ENRICHED_TFS_G2_M',
#  'PULVER_FOREY_CELLCYCLE_PEAKING_G1_S',
#  'PULVER_FOREY_CELLCYCLE_PEAKING_G2_M',
#  'PULVER_FOREY_PERTURB_ACCUMULATION_G1_S',
#  'PULVER_FOREY_PERTURB_ACCUMULATION_G2_M',
#  'PULVER_FOREY_PERTURB_ATTRITION_G1_S',
#  'PULVER_FOREY_PERTURB_ATTRITION_G2_M',
#  'REACTOME_ABERRANT_REGULATION_OF_MITOTIC_EXIT_IN_CANCER_DUE_TO_RB1_DEFECTS',
#  'REACTOME_ABERRANT_REGULATION_OF_MITOTIC_G1_S_TRANSITION_IN_CANCER_DUE_TO_RB1_DEFECTS',
#  'REACTOME_ACTIVATED_NTRK2_SIGNALS_THROUGH_CDK5',
#  'REACTOME_ACTIVATION_OF_APC_C_AND_APC_C_CDC20_MEDIATED_DEGRADATION_OF_MITOTIC_PROTEINS',
#  'REACTOME_APC_C_CDH1_MEDIATED_DEGRADATION_OF_CDC20_AND_OTHER_APC_C_CDH1_TARGETED_PROTEINS_IN_LATE_MITOSIS_EARLY_G1',
#  'REACTOME_APC_C_MEDIATED_DEGRADATION_OF_CELL_CYCLE_PROTEINS',
#  'REACTOME_CDK_MEDIATED_PHOSPHORYLATION_AND_REMOVAL_OF_CDC6',
#  'REACTOME_CELL_CYCLE',
#  'REACTOME_CELL_CYCLE_CHECKPOINTS',
#  'REACTOME_CELL_CYCLE_MITOTIC',
#  'REACTOME_CHK1_CHK2_CDS1_MEDIATED_INACTIVATION_OF_CYCLIN_B_CDK1_COMPLEX',
#  'REACTOME_CYCLIN_A_B1_B2_ASSOCIATED_EVENTS_DURING_G2_M_TRANSITION',
#  'REACTOME_CYCLIN_A_CDK2_ASSOCIATED_EVENTS_AT_S_PHASE_ENTRY',
#  'REACTOME_DISEASES_OF_MITOTIC_CELL_CYCLE',
#  'REACTOME_DRUG_MEDIATED_INHIBITION_OF_CDK4_CDK6_ACTIVITY',
#  'REACTOME_FBXL7_DOWN_REGULATES_AURKA_DURING_MITOTIC_ENTRY_AND_IN_EARLY_MITOSIS',
#  'REACTOME_FOXO_MEDIATED_TRANSCRIPTION_OF_CELL_CYCLE_GENES',
#  'REACTOME_G1_S_DNA_DAMAGE_CHECKPOINTS',
#  'REACTOME_G1_S_SPECIFIC_TRANSCRIPTION',
#  'REACTOME_G2_M_CHECKPOINTS',
#  'REACTOME_G2_M_DNA_DAMAGE_CHECKPOINT',
#  'REACTOME_G2_M_DNA_REPLICATION_CHECKPOINT',
#  'REACTOME_G2_PHASE',
#  'REACTOME_INHIBITION_OF_THE_PROTEOLYTIC_ACTIVITY_OF_APC_C_REQUIRED_FOR_THE_ONSET_OF_ANAPHASE_BY_MITOTIC_SPINDLE_CHECKPOINT_COMPONENTS',
#  'REACTOME_MASTL_FACILITATES_MITOTIC_PROGRESSION',
#  'REACTOME_MITOTIC_G1_PHASE_AND_G1_S_TRANSITION',
#  'REACTOME_MITOTIC_G2_G2_M_PHASES',
#  'REACTOME_MITOTIC_METAPHASE_AND_ANAPHASE',
#  'REACTOME_MITOTIC_PROMETAPHASE',
#  'REACTOME_MITOTIC_PROPHASE',
#  'REACTOME_MITOTIC_SPINDLE_CHECKPOINT',
#  'REACTOME_MITOTIC_TELOPHASE_CYTOKINESIS',
#  'REACTOME_P75NTR_NEGATIVELY_REGULATES_CELL_CYCLE_VIA_SC1',
#  'REACTOME_POSTMITOTIC_NUCLEAR_PORE_COMPLEX_NPC_REFORMATION',
#  'REACTOME_PTK6_REGULATES_CELL_CYCLE',
#  'REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXES',
#  'REACTOME_RECRUITMENT_OF_NUMA_TO_MITOTIC_CENTROSOMES',
#  'REACTOME_REGULATION_OF_MITF_M_DEPENDENT_GENES_INVOLVED_IN_CELL_CYCLE_AND_PROLIFERATION',
#  'REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_TRANSITION',
#  'REACTOME_RUNX3_REGULATES_CDKN1A_TRANSCRIPTION',
#  'REACTOME_TFAP2_AP_2_FAMILY_REGULATES_TRANSCRIPTION_OF_CELL_CYCLE_FACTORS',
#  'REACTOME_THE_ROLE_OF_GTSE1_IN_G2_M_PROGRESSION_AFTER_G2_CHECKPOINT',
#  'REACTOME_TP53_REGULATES_TRANSCRIPTION_OF_ADDITIONAL_CELL_CYCLE_GENES_WHOSE_EXACT_ROLE_IN_THE_P53_PATHWAY_REMAIN_UNCERTAIN',
#  'REACTOME_TP53_REGULATES_TRANSCRIPTION_OF_CELL_CYCLE_GENES',
#  'REACTOME_TP53_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_G1_CELL_CYCLE_ARREST',
#  'REACTOME_TP53_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_G2_CELL_CYCLE_ARREST',
#  'REICHERT_MITOSIS_LIN9_TARGETS',
#  'ROSTY_CERVICAL_CANCER_PROLIFERATION_CLUSTER',
#  'SA_G1_AND_S_PHASES',
#  'SA_G2_AND_M_PHASES',
#  'SCIAN_CELL_CYCLE_TARGETS_OF_TP53_AND_TP73_DN',
#  'SCIAN_CELL_CYCLE_TARGETS_OF_TP53_AND_TP73_UP',
#  'STEGMEIER_PREMITOTIC_CELL_CYCLE_REGULATORS',
#  'WHITFIELD_CELL_CYCLE_G1_S',
#  'WHITFIELD_CELL_CYCLE_G2',
#  'WHITFIELD_CELL_CYCLE_G2_M',
#  'WHITFIELD_CELL_CYCLE_LITERATURE',
#  'WHITFIELD_CELL_CYCLE_M_G1',
#  'WHITFIELD_CELL_CYCLE_S',
#  'WP_CELL_CYCLE',
#  'WP_DYRK1A_INVOLVEMENT_REGARDING_CELL_PROLIFERATION_IN_BRAIN_DEVELOPMENT',
#  'WP_FGFR3_SIGNALING_IN_CHONDROCYTE_PROLIFERATION_AND_TERMINAL_DIFFERENTIATION',
#  'WP_G1_TO_S_CELL_CYCLE_CONTROL',
#  'WP_H19_RBE2F1_AND_CDKBETACATENIN_IN_COLORECTAL_CANCER',
#  'WP_MIR124_PREDICTED_INTERACTIONS_WITH_CELL_CYCLE_AND_DIFFERENTIATION',
#  'WU_APOPTOSIS_BY_CDKN1A_NOT_VIA_TP53',
#  'WU_APOPTOSIS_BY_CDKN1A_VIA_TP53',
#  'ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_24HR',
#  'ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_2HR',
#  'ZHOU_CELL_CYCLE_GENES_IN_IR_RESPONSE_6HR']

# %%
# Number of genesets containing that number of genes
df_genesets_cell_cycle["n_genes"] = df_genesets_cell_cycle.geneSymbols.apply(lambda x: len(x))

print("Genesets with msot genes:")
display(df_genesets_cell_cycle.sort_values("n_genes", ascending=False).head(3))

df_genesets_cell_cycle.n_genes.plot(kind="hist", figsize=(20, 3), ylabel="number genesets", bins=100, logy=True)
# Out:
# Genesets with msot genes:
#                                        set_name collection systematicName  \
# 19134                           GOBP_CELL_CYCLE   C5:GO:BP          M9669
# 57668  HE_LIM_SUN_FETAL_LUNG_C2_CYCLING_DC_CELL         C8         M45722
# 20256                   GOBP_CELL_CYCLE_PROCESS   C5:GO:BP         M17773
#
#            pmid                                        exactSource  \
# 19134                                                   GO:0007049
# 57668  36493756  Table S1. Cell-type markers, related to Figure...
# 20256                                                   GO:0022402
#
#                                       externalDetailsURL  \
# 19134  http://amigo.geneontology.org/amigo/term/GO:00...
# 57668                          https://lungcellatlas.org
# 20256  http://amigo.geneontology.org/amigo/term/GO:00...
#
#                                                msigdbURL  \
# 19134  https://www.gsea-msigdb.org/gsea/msigdb/human/...
# 57668  https://www.gsea-msigdb.org/gsea/msigdb/human/...
# 20256  https://www.gsea-msigdb.org/gsea/msigdb/human/...
#
#                                              geneSymbols filteredBySimilarity  \
# 19134  [AAAS, AATF, ABCB1, ABL1, ABRAXAS1, ABRAXAS2, ...                   []
# 57668  [AAAS, AARS1, AARS2, AASDH, ABCB7, ABCB8, ACAA...                   []
# 20256  [AAAS, ABCB1, ABRAXAS1, ABRAXAS2, ACTB, ACTL6A...                   []
#
#       externalNamesForSimilarTerms             source_file  n_genes
# 19134                           []   c5.go.v2025.1.Hs.json     1705
# 57668                           []  msigdb.v2025.1.Hs.json     1423
# 20256                           []   c5.go.v2025.1.Hs.json     1348
# <Axes: ylabel='number genesets'>

# %%
# Are there duplicated genes in a single egeneset
df_genesets_cell_cycle["has_duplicated_genes"] = df_genesets_cell_cycle.geneSymbols.apply(lambda x: len(x) != len(set(x)))
print("Number of genesets with duplicated genes:", df_genesets_cell_cycle["has_duplicated_genes"].sum())
# Out:
# Number of genesets with duplicated genes: 0

# %% [markdown]
# # Count in how many genesets each gene is present (*Prevalence* metric)

# %%
gene_counts_df = dataf.gene_set_counts(df_genesets_cell_cycle)

# create a label for later
gene_counts_df["is_guaranteed"] = False

print("Number of positive genes:", gene_counts_df.shape[0])
display(gene_counts_df)
print(gene_counts_df.gene.to_list())
# plot ditruction
gene_counts_df.geneset_count.plot(kind="hist", logy=True, bins=100, ylabel="number genes", xlabel="number of genesets in which one gene appears")
# Out:
# Processing gene sets: 100%|██████████| 291/291 [00:00<00:00, 26763.35it/s]
# Number of positive genes: 7288
#          gene  geneset_count  is_guaranteed
# 0        CDK1             97          False
# 1       CCNB1             83          False
# 2        PLK1             75          False
# 3       BIRC5             74          False
# 4         RB1             73          False
# ...       ...            ...            ...
# 7283     SCAI              1          False
# 7284    SCML1              1          False
# 7285  SERINC5              1          False
# 7286    SIRPG              1          False
# 7287     SIT1              1          False
#
# [7288 rows x 3 columns]
# ['CDK1', 'CCNB1', 'PLK1', 'BIRC5', 'RB1', 'E2F1', 'AURKB', 'CDK2', 'CDKN1A', 'CCND1', 'CDC20', 'MAD2L1', 'CDC6', 'UBE2C', 'CDCA8', 'CCNE1', 'TP53', 'CCNE2', 'CENPF', 'NDC80', 'CHEK1', 'INCENP', 'AURKA', 'BUB1', 'CCNA2', 'SKA1', 'MAD1L1', 'FBXO5', 'CHEK2', 'ZWINT', 'CDKN1B', 'CDC25C', 'CDK4', 'RAD21', 'WEE1', 'FZR1', 'DTL', 'ESPL1', 'SKA3', 'CDC23', 'CCNB2', 'BRCA1', 'CDC25A', 'CDC16', 'BUB1B', 'ANAPC7', 'E2F3', 'E2F2', 'ATM', 'ORC1', 'TFDP1', 'CDC7', 'NUSAP1', 'NEK2', 'KNL1', 'TTK', 'NUF2', 'TPR', 'CDC25B', 'CCND3', 'RRM2', 'BUB3', 'TOPBP1', 'SPDL1', 'CENPE', 'CLSPN', 'RPA2', 'DLGAP5', 'ANAPC5', 'CDK5RAP2', 'ANAPC11', 'ANAPC15', 'KNTC1', 'MAD2L1BP', 'ATR', 'DONSON', 'BLM', 'BARD1', 'CCND2', 'PKMYT1', 'PRAP1', 'ZW10', 'SPC25', 'CENPJ', 'CDCA5', 'RRM1', 'MCM2', 'CDC45', 'CDC14B', 'EZH2', 'PCNA', 'RBBP8', 'TPX2', 'CDC27', 'DYNC1LI1', 'CDK6', 'RBL1', 'KIF23', 'TRIP13', 'KIF20B', 'CCNA1', 'XRCC3', 'HUS1', 'MRE11', 'ABRAXAS1', 'TICRR', 'MCM6', 'UBE2S', 'SPC24', 'ZWILCH', 'STIL', 'MDM2', 'CHMP4C', 'BRCC3', 'GEN1', 'KIF14', 'BABAM2', 'SMC2', 'SKP2', 'RAD17', 'DBF4', 'NBN', 'SMC4', 'MYC', 'VPS4A', 'RAB11A', 'UIMC1', 'RBL2', 'MCM3', 'RACGAP1', 'RGCC', 'KIF2C', 'CDKN2D', 'TAOK1', 'PTTG1', 'MKI67', 'RCC2', 'PPP2CA', 'MAP3K20', 'LCMT1', 'E2F7', 'CDT1', 'ANLN', 'CDKN2A', 'NUMA1', 'BABAM1', 'PRC1', 'SASS6', 'MAD2L2', 'VPS4B', 'KIF11', 'RFWD3', 'CENPA', 'BRCA2', 'CDKN2C', 'ANAPC4', 'CUL4A', 'CUL3', 'MCM4', 'FOXO4', 'CDKN2B', 'RAD50', 'DBF4B', 'TOP2A', 'CCNF', 'NSMCE2', 'CKS2', 'NAE1', 'NUP62', 'ZNF207', 'BRD4', 'HUS1B', 'TGFB1', 'MTBP', 'CDKN3', 'PRKDC', 'PPP1R10', 'APC', 'RAD51C', 'TIPIN', 'DUSP1', 'MAPRE1', 'TREX1', 'PLK3', 'ANAPC1', 'FOXN3', 'MDC1', 'PRP4K', 'ANAPC2', 'RINT1', 'TRIM39', 'AKT1', 'H2AX', 'ZNF830', 'ETAA1', 'HNRNPU', 'KIF20A', 'SMC1A', 'RCC1', 'CDKN1C', 'CLASP1', 'USP44', 'CKS1B', 'MIR29A', 'CDK7', 'TRIAP1', 'TAOK2', 'RAD9A', 'CKAP5', 'KLHL22', 'MSH2', 'KAT5', 'RAD51', 'MUC1', 'MYBL2', 'STAG1', 'IER3', 'CDK5RAP3', 'DNA2', 'BRSK1', 'TK1', 'PPP2R1A', 'MCM7', 'STOX1', 'NABP2', 'FGF10', 'SDE2', 'MBTPS1', 'IK', 'INTS3', 'GIGYF2', 'ECT2', 'E2F8', 'ZFYVE19', 'NCAPH', 'SYF2', 'TAOK3', 'WAC', 'FBXO31', 'MBTPS2', 'NOP53', 'MRNIP', 'CHMP2A', 'HASPIN', 'PAFAH1B1', 'CEP55', 'RAD9B', 'INIP', 'DGKZ', 'SMC3', 'KIF22', 'CHMP7', 'CDC14A', 'HSPA2', 'SIN3A', 'RHNO1', 'RPS27L', 'BORA', 'ADAMTS1', 'CDK10', 'CDC73', 'CPSF3', 'FOXM1', 'CHMP4B', 'EIF4G1', 'AIF1', 'FAM83D', 'GMNN', 'BRD7', 'CCNH', 'NCAPH2', 'ATAD5', 'RPTOR', 'SIRT2', 'SMARCD3', 'MNAT1', 'SPAG5', 'KIFC1', 'PABIR1', 'MIR222', 'NDE1', 'MTA3', 'TEX14', 'PSMG2', 'CUL1', 'MIR495', 'MEPCE', 'MCM5', 'KIF18A', 'TERT', 'STAG2', 'MZT1', 'FANCD2', 'PLCB1', 'NABP1', 'TUBB', 'RRM2B', 'EME1', 'KAT2B', 'PLRG1', 'RNASEH2B', 'RDX', 'TUBB4B', 'DLG1', 'NCAPD3', 'KMT2E', 'JADE1', 'LSM10', 'TYMS', 'ANAPC10', 'KANK2', 'CUL4B', 'NCAPD2', 'CENPM', 'FHL1', 'KIF4A', 'CENPK', 'PKD2', 'CHFR', 'FEN1', 'LSM11', 'PINX1', 'ASPM', 'CYP1A1', 'ANXA1', 'DYNC1H1', 'MIR221', 'BCL2', 'MBLAC1', 'MIR193A', 'MIR214', 'MIR16-1', 'SKA2', 'ADAM17', 'MIR15B', 'DDR2', 'CHMP6', 'INO80', 'ANKRD17', 'MIR15A', 'KLF4', 'NCAPG', 'CLASP2', 'NEUROG1', 'MIR26A1', 'CDK2AP2', 'CDC26', 'KCNA5', 'H4C3', 'EGFR', 'DDX3X', 'PCLAF', 'MIR515-1', 'MIR372', 'MIR29C', 'MUS81', 'MIR208A', 'MIR520A', 'MIR520H', 'CHMP3', 'TFDP3', 'CEP192', 'PBX1', 'UBE2E2', 'TUBG1', 'STK35', 'PTENP1-AS', 'MIR519D', 'RAD1', 'GPR132', 'ATF2', 'EME2', 'ZNF655', 'GFI1B', 'HEXIM2', 'CCSAP', 'PHOX2B', 'POC1A', 'UHRF1', 'NEK11', 'MIIP', 'PSMD13', 'MASTL', 'GPSM2', 'YWHAE', 'XPC', 'DCUN1D3', 'RFC4', 'CTDSP1', 'WDR76', 'DCTN1', 'GTPBP4', 'SMARCB1', 'SPAST', 'POLDIP2', 'PLK4', 'RAD51B', 'SLFN11', 'TACC3', 'WNT10B', 'HAUS8', 'CENPH', 'CCL2', 'CACNB4', 'MIR19B1', 'HMGB2', 'DACT1', 'FBXO7', 'CRLF3', 'CTDSPL', 'CTDSP2', 'FAM107A', 'SEH1L', 'AVEN', 'CHMP4A', 'PTEN', 'CDC42', 'ATRIP', 'CHMP2B', 'SGO2', 'MIS12', 'RFPL1', 'KPNB1', 'MIR29B1', 'PDIK1L', 'GPNMB', 'BMP4', 'INHBA', 'MIR195', 'BCL7A', 'PSMD14', 'BTN2A2', 'MIR133A1', 'NUP37', 'NPM1', 'MIR137', 'MIR133B', 'MIR892B', 'ACVR1', 'MIR3 ...
# <Axes: xlabel='number of genesets in which one gene appears', ylabel='number genes'>

# %%
# geneset count across all genesets
tmp = dataf.gene_set_counts(df_genesets, subset_genes=gene_counts_df.gene.to_list())
tmp.rename(columns={"geneset_count": "geneset_count_all"}, inplace=True)

gene_counts_df = pd.merge(gene_counts_df, tmp, on="gene", how="left")

print("\nAre there Nan?", gene_counts_df.geneset_count_all.isna().sum())

display(gene_counts_df)
gene_counts_df.geneset_count_all.plot(kind="hist", logy=True, bins=100, ylabel="number genes", xlabel="number of genesets in which one gene appears")
# Out:
# Processing gene sets:  60%|█████▉    | 20914/35134 [00:00<00:00, 32332.98it/s]
# Processing gene sets: 100%|██████████| 35134/35134 [00:01<00:00, 25091.31it/s]
# Are there Nan? 0
#          gene  geneset_count  is_guaranteed  geneset_count_all
# 0        CDK1             97          False                894
# 1       CCNB1             83          False                588
# 2        PLK1             75          False                605
# 3       BIRC5             74          False                554
# 4         RB1             73          False                821
# ...       ...            ...            ...                ...
# 7283     SCAI              1          False                311
# 7284    SCML1              1          False                179
# 7285  SERINC5              1          False                326
# 7286    SIRPG              1          False                116
# 7287     SIT1              1          False                199
#
# [7288 rows x 4 columns]
# <Axes: xlabel='number of genesets in which one gene appears', ylabel='number genes'>

# %% [markdown]
# # Add Guaranteed genes
#
# Read them from Julie's csv file.
#
# Add them with:
# - max-freq IF they are not present in original genesets
# - same freq IF they are alredy present in the genesets

# %%
### 1) Read spefic csv
guarented_genes_df = pd.read_csv(config["data_paths"]["guaranted_positive_genes"], sep='\t')

### 2) Extarct the single gene names
all_values = guarented_genes_df.to_numpy().flatten().tolist()
all_values = [x for x in all_values if pd.notna(x)] # remove nan
all_values = list(set(all_values)) # remove duplicated
print("Number of guaranted genes: ", len(all_values))

# Find genes in A but NOT in B
genes_guaranted = set(all_values)
genes_original = set(gene_counts_df['gene'])
genes_in_guaranted_only = genes_guaranted.difference(genes_original)
genes_in_intersection = genes_guaranted.intersection(genes_original)
print(f"Genes in guarented_genes_df only: {len(genes_in_guaranted_only)} \n{genes_in_guaranted_only}")
#gene_counts_df[gene_counts_df.gene.isin(genes_in_intersection)].geneset_count.plot(kind="hist", bins=NUMBER_POSITIVE_GENESETS)

### 3) Create new df with NEW genes
    # the one that oerlaps are alredy rpesent and will get the same freqeuncy
guarented_genes_df = pd.DataFrame({
    'gene': list(genes_in_guaranted_only),
    'geneset_count': max(gene_counts_df.geneset_count), # Use as Freq the max (as these genes are guaranted)
    "is_guaranteed": True,
    'geneset_count_all': max(gene_counts_df.geneset_count_all), # Use as Freq the max (as these genes are guaranted)
})
# Out:
# Number of guaranted genes:  146
# Genes in guarented_genes_df only: 6
# {'H2AFZ', 'HN1', 'MLF1IP', 'HIST1H4C', 'KIAA0101', 'FAM64A'}

# %%
# append to existing gene_frequency_df
gene_frequency_df = pd.concat([gene_counts_df, guarented_genes_df], ignore_index=True)

# give +1 to freq for the overalpping
gene_frequency_df.loc[gene_frequency_df['gene'].isin(genes_guaranted), 'geneset_count'] = gene_frequency_df.loc[gene_frequency_df['gene'].isin(genes_guaranted), 'geneset_count'] + 1

# Update is_guaranteed for overlapping genes
gene_frequency_df.loc[gene_frequency_df['gene'].isin(genes_guaranted), 'is_guaranteed'] = True

# ATTENTION: Drop duplicates, keeping **the last occurrence** (i.e., from new_genes_df) --< so gurated genes have max freq
#gene_frequency_df = gene_frequency_df.drop_duplicates(subset='gene', keep='last')

# Sort and reset index
gene_frequency_df.sort_values(by=['geneset_count', 'gene'], ascending=[False, True], inplace=True)
gene_frequency_df.reset_index(drop=True, inplace=True)

display(display(gene_frequency_df.head(5)))
print("Total number of genes, after addeding guarated:", gene_frequency_df.shape[0])
# Out:
#        gene  geneset_count  is_guaranteed  geneset_count_all
# 0      CDK1             98           True                894
# 1    FAM64A             98           True               1755
# 2     H2AFZ             98           True               1755
# 3  HIST1H4C             98           True               1755
# 4       HN1             98           True               1755
# None
# Total number of genes, after addeding guarated: 7294

# %% [markdown]
# # Label "ambiguos" genes
#
# Mark as "ambiguos" genes with too few Gene Sets.
#
# Threshold is min{MIN_NUMBER, PERCENTAGE x total_positive_genesets}

# %%
MIN = max([
        config["dataset_creation"]["min_freq_to_be_positive_gene"], 
        int(config["dataset_creation"]["percentage_number_positive_genesets"] * NUMBER_POSITIVE_GENESETS)
    ])
print("Gene is ambiguos if preset in less than:", MIN, "genesets")

# give a label to gene that overcome the thr
gene_frequency_df["label"] = gene_frequency_df.geneset_count.apply(lambda x: 'positive' if x > MIN else 'ambigous')

# add perdcentage
    # If a gene has a count of NUMBER_POSITIVE_GENESETS, that's 100% of all gene sets.
gene_frequency_df['geneset_percent'] = (gene_frequency_df['geneset_count'] / NUMBER_POSITIVE_GENESETS) * 100

display(gene_frequency_df)
print(gene_frequency_df.label.value_counts())
print(f"Only {(100*gene_frequency_df.label.value_counts()['positive']/gene_frequency_df.shape[0]):1f}% are real positives.")
# Out:
# Gene is ambiguos if preset in less than: 7 genesets
#           gene  geneset_count  is_guaranteed  geneset_count_all     label  \
# 0         CDK1             98           True                894  positive
# 1       FAM64A             98           True               1755  positive
# 2        H2AFZ             98           True               1755  positive
# 3     HIST1H4C             98           True               1755  positive
# 4          HN1             98           True               1755  positive
# ...        ...            ...            ...                ...       ...
# 7289   ZSCAN20              1          False                 76  ambigous
# 7290   ZSCAN22              1          False                 78  ambigous
# 7291    ZSCAN9              1          False                 80  ambigous
# 7292    ZSWIM4              1          False                108  ambigous
# 7293      ZUP1              1          False                 88  ambigous
#
#       geneset_percent
# 0           33.676976
# 1           33.676976
# 2           33.676976
# 3           33.676976
# 4           33.676976
# ...               ...
# 7289         0.343643
# 7290         0.343643
# 7291         0.343643
# 7292         0.343643
# 7293         0.343643
#
# [7294 rows x 6 columns]
# label
# ambigous    6146
# positive    1148
# Name: count, dtype: int64
# Only 15.738964% are real positives.

# %%
# Plot percentage of genes (y-axis) that appear in that percetage (x-axis) of genes sets
NUM_BINS = 100
bin_edges = np.linspace(0, 100, NUM_BINS + 1)

plt.figure(figsize=(20, 5))
sns.histplot(
    data=gene_frequency_df,
    x='geneset_percent',  
    bins=bin_edges,       # Define 10 bins for the X-axis (e.g., 0-10%, 10-20%, etc.)
    stat="percent",       # Y-axis shows the percentage of genes in each bin
    kde=False,
    color='teal',
    edgecolor='black',

    cumulative=True,   
)
plt.title('Cumulative Distribution of Genes by Gene Set Coverage', fontsize=14)
plt.xlabel('Gene Set Coverage (% of Total Gene Sets)', fontsize=12)
plt.ylabel('Cumulative Percentage of Total Genes', fontsize=12)
plt.axvline(x=MIN, color='red', linestyle='--', linewidth=1.5, label='Threshold')
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# # Save

# %%
gene_frequency_df.to_csv(config["data_paths"]["broad_positive_genes"], index=False)
df_genesets_cell_cycle.to_csv(config["data_paths"]["positive_genesets"], index=False)
